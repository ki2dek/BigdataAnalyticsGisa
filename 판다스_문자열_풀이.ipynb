# %% [markdown]
# <a href="https://colab.research.google.com/github/ki2dek/BigdataAnalyticsGisa/blob/main/%ED%8C%90%EB%8B%A4%EC%8A%A4_%EB%AC%B8%EC%9E%90%EC%97%B4_%ED%92%80%EC%9D%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 문자열(심화)

# %%
import pandas as pd
df = pd.DataFrame({'A': ['블루베리 스무디', '딸기 스무디', '딸기 바나나 스무디'],
                   'B': [10, 20, 30],
                   'C': ['추천/신메뉴', '신메뉴/할인', '사이즈업/추천'],
                   'D': ['ab cd', 'AB CD', 'ab cd']
                   })
df
# Out:
#             A   B        C       D
# 0    블루베리 스무디  10   추천/신메뉴   ab cd
# 1      딸기 스무디  20   신메뉴/할인   AB CD
# 2  딸기 바나나 스무디  30  사이즈업/추천  ab cd

# %%
# replace, 전체 문자가 일치해야 변경
df['A'] = df['A'].replace('스무디', '에이드')
df
# Out:
#             A   B        C      D
# 0    블루베리 스무디  10   추천/신메뉴  ab cd
# 1      딸기 스무디  20   신메뉴/할인  AB CD
# 2  딸기 바나나 스무디  30  사이즈업/추천  ab cd

# %%
# str.replace, 일부 일치하는 문자 변경
df['A'] = df['A'].str.replace('스무디', '에이드')
df
# Out:
#             A   B        C      D
# 0    블루베리 에이드  10   추천/신메뉴  ab cd
# 1      딸기 에이드  20   신메뉴/할인  AB CD
# 2  딸기 바나나 에이드  30  사이즈업/추천  ab cd

# %%
# replace 데이터프레임
df.replace('블루베리 에이드', '청포도 에이드')
# Out:
#             A   B        C      D
# 0     청포도 에이드  10   추천/신메뉴  ab cd
# 1      딸기 에이드  20   신메뉴/할인  AB CD
# 2  딸기 바나나 에이드  30  사이즈업/추천  ab cd

# %%
# 숫자 변경
df['B'] = df['B'].replace(10, 100)
df
# Out:
#             A    B        C      D
# 0    블루베리 에이드  100   추천/신메뉴  ab cd
# 1      딸기 에이드   20   신메뉴/할인  AB CD
# 2  딸기 바나나 에이드   30  사이즈업/추천  ab cd

# %%
# 숫자 변경(str.replace)
# df['B'] = df['B'].str.replace(10, 100)
# df

# %%
# 어절 나누기
df['A'].str.split()
# Out:
# 0       [블루베리, 에이드]
# 1         [딸기, 에이드]
# 2    [딸기, 바나나, 에이드]
# Name: A, dtype: object

# %%
# 어절 나눈 후 첫 번째 값
df['A'].str.split().str[0]
# Out:
# 0    블루베리
# 1      딸기
# 2      딸기
# Name: A, dtype: object

# %%
# 어절 나눈 후 첫 번째 값을 새로운 컬럼으로 대입
df['E'] = df['A'].str.split().str[0]
df
# Out:
#             A    B        C      D     E
# 0    블루베리 에이드  100   추천/신메뉴  ab cd  블루베리
# 1      딸기 에이드   20   신메뉴/할인  AB CD    딸기
# 2  딸기 바나나 에이드   30  사이즈업/추천  ab cd    딸기

# %%
# 어절 나누기(/)
df['C'].str.split('/')
# Out:
# 0     [추천, 신메뉴]
# 1     [신메뉴, 할인]
# 2    [사이즈업, 추천]
# Name: C, dtype: object

# %%
# 특정 문자 찾기 (contains)
df['A'].str.contains('딸기')
# Out:
# 0    False
# 1     True
# 2     True
# Name: A, dtype: bool

# %%
# 특정 문자 찾은 후 새컬럼에 대입 (contains)
df['is딸기'] = df['A'].str.contains('딸기')
df
# Out:
#             A    B        C      D     E   is딸기
# 0    블루베리 에이드  100   추천/신메뉴  ab cd  블루베리  False
# 1      딸기 에이드   20   신메뉴/할인  AB CD    딸기   True
# 2  딸기 바나나 에이드   30  사이즈업/추천  ab cd    딸기   True

# %%
# 데이터
menu = pd.Series(['맛난버거 세트', '매운 치킨버거', '더블 치즈버거'])

# %%
# 특정 값이 있는지 확인하기 (isin)
menu.isin(['맛난버거 세트', '더블 치즈버거'])
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
# 특정 단어가 있는지 확인하기 (isin)
menu.isin(['세트'])
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
# 특정 단어가 있는지 확인하기 (contains)
menu.str.contains('세트')
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
# 문자 길이
df['A'].str.len()
# Out:
# 0     8
# 1     6
# 2    10
# Name: A, dtype: int64

# %%
# 대소문자 구분
'AB cd' == 'ab CD'
# Out:
# False

# %%
# 소문자로 변경
df['D'].str.lower()
# Out:
# 0    ab cd
# 1    ab cd
# 2    ab cd
# Name: D, dtype: object

# %%
# 대문자로 변경
df['D'].str.upper()
# Out:
# 0    AB CD
# 1    AB CD
# 2    AB CD
# Name: D, dtype: object

# %%
df2 = pd.DataFrame({'A': ['블루베리 스무디', '딸기 스무디', '딸기 바나나 스무디'],
                   'B': [10, 20, 30],
                   'C': ['추천/신메뉴', '신메뉴/할인', '사이즈업/추천'],
                   'D': ['ab cd', 'AB CD', 'ab cd ']
                   })

# %%
# AB CD와 같은가?
df2['D'] = df2['D'].str.upper()
df2['D'] == 'AB CD'
# Out:
# 0     True
# 1     True
# 2    False
# Name: D, dtype: bool

# %%
# 공백 제거
df2['D'] = df2['D'].str.replace(" ","")
df2
# Out:
#             A   B        C     D
# 0    블루베리 스무디  10   추천/신메뉴  ABCD
# 1      딸기 스무디  20   신메뉴/할인  ABCD
# 2  딸기 바나나 스무디  30  사이즈업/추천  ABCD

# %%
# 슬라이싱(str)
df2['D'].str[:2]
# Out:
# 0    AB
# 1    AB
# 2    AB
# Name: D, dtype: object

# %%
# 슬라이싱
df2['D'][:2]
# Out:
# 0    ABCD
# 1    ABCD
# Name: D, dtype: object

# %%
# 데이터
df = pd.DataFrame({'date':['2024년 3월', '2024년 4월', '2025년 5월']})

# %%
# 연도
df['date'].str[:4]
# Out:
# 0    2024
# 1    2024
# 2    2025
# Name: date, dtype: object

# %%
# 월
df['date'].str[6:7]
# Out:
# 0    3
# 1    4
# 2    5
# Name: date, dtype: object
